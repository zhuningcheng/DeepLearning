# %%
from modelscope import snapshot_download

# %%
model_dir = snapshot_download(model_id = "BAAI/bge-large-zh-v1.5", # 选择模型
                              cache_dir = r"D:\PycharmProjects\pyjupyter\深度学习\深度学习代码\RAG检索增强生成\model" # 模型下载到哪个位置
                             )
# Out:
# ...
# 2025-11-02 10:43:19,380 - modelscope - INFO - Creating symbolic link [D:\PycharmProjects\pyjupyter\深度学习\深度学习代码\RAG检索增强生成\model\BAAI\bge-large-zh-v1.5].
# 2025-11-02 10:43:19,419 - modelscope - WARNING - Failed to create symbolic link D:\PycharmProjects\pyjupyter\深度学习\深度学习代码\RAG检索增强生成\model\BAAI\bge-large-zh-v1.5 for D:\PycharmProjects\pyjupyter\深度学习\深度学习代码\RAG检索增强生成\model\BAAI\bge-large-zh-v1___5.
